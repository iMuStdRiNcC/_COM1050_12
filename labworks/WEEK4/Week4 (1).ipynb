# %%
#bai1

n = int(input(""))
i1 = 0
for i in range(1,n+1):
    i1 += i
    
    
print(i1)

# %%
#bai2

n =  int(input(" "))

if n < 2:
    print("ko phai so nguyen to")
    
else:
    for i in range(2,n):
        if n%i == 0:
            print("ko phai so nguyen to")
            break
        else:
            print("so nguyen to")
            break

# %%
#bai3 
n =  int(input(" "))
i1 = 1
for i in range(1,n+1):
    i1 = i1*i

print(i1)

# %%
#bai4
n =  int(input(" "))
n = abs(n)
count = 0
while n > 0:
    n //= 10
    count +=1
    
print(count)

# %%
#bai6
a=int(input(" "))
b=int(input(" "))

sumprime = 0

for i in range (a,b):
    if i < 2:
        continue
    for j in range(2, i):
        if i % j == 0:
            break

    else:
        sumprime += i
            
print(sumprime)

# %%
#bai7
n = int(input("(n ≥ 2): "))

i = 2
while n > 1:
    if n % i == 0:
        n //= i
    else:
        i += 1
print(i)

# %%
#w4a8
def reverse_number(n):
    return int(str(n)[::-1])

n = int(input("enter your number: "))

steps = 0
while str(n) != str(n)[::-1]:
    n = n + reverse_number(n)
    steps += 1

print("steps:", steps)
print("paindrome:", n)

# %%
#w4a9
n = int(input().strip())

res = []
i = 1
while i * i <= n:
    sq = i * i
    s = str(sq)
    if len(set(s)) == len(s): 
        res.append(str(sq))
    i += 1

if res:
    print(" ".join(res))
else:
    print("(no number)")

# %%
#w4a10

# %%
#W4a11

n = int(input("number (<10^6): "))
even_divisor_Count = 0
for number in range(1,n+1):
    if n % number == 0:   
        if number % 2==0:
            even_divisor_Count += 1
            
        else:
            continue
    else:
        continue
    
print(even_divisor_Count)

# %%
#W4A12

X = int(input("moneyd deposited: "))
n = 0.7/100
months_after = int(input("how many months after initial deposit ? "))

for month in range(1,months_after + 1):
    X = X+ n*X
    
print(int(X))

# %%
#W4A13

number_1 = int(input("number 1: "))
number_2 = int(input("number 2: "))
divisor_addition = 0
for n in range(1,number_1):
    if number_1 % n == 0:
        divisor_addition += n
    else:
        continue
    
if divisor_addition == number_2:
    print(True)
else:
    print(False)

# %%
#W4A14

m = int(input("number 1: "))
n = int(input("number 2: "))

division= []
if m<0 or n<0:
    print("m and n must be above 0 ")

if m>n:
    for i in range(1,n+1):
        if m%i==0 and n%i==0:
            division.append(i)
        else:
            pass
        
else:
    for i in range(1,m+1):
        if m%i==0 and n%i==0:
            division.append(i)
        else:
            pass
        
print(max(division))

# %%
#W4A15
dogs_and_chickens = int(input("total dogs and chickens: "))
total_legs = int(input("total legs: "))
if total_legs % 2 == 0:
    dogs = (total_legs-2*dogs_and_chickens)/2
    print(f"dogs:{dogs}")
    print(f"chickens:{dogs_and_chickens-dogs}")
else:
    print("invalid")

# %%
#W4A16
for i in range(1,100):
    if i % 2==0:
        if i % 3 ==0:
            print(i)
        else:
            continue
    else:
        continue

# %%
#W4A17

number_a = int(input("number_a: "))
for i in range(1,11):
    print(f"{number_a} * {i} = {number_a*i}")

# %%
#W4A18
number_a = int(input("number_a: "))
number_b = int(input("number_b: "))

if number_a>number_b:
    for i in range(1,number_a):
        if number_a % i==0  and number_b % i ==0:
            print(i)
            
else:
    for i in range(1,number_b):
        if number_a % i==0  and number_b % i ==0:
            print(i)

# %%
#W4A19

n = int(input("n(n<=1000): "))
for i in range(2,n+1):
    if i % 2 == 0:
        print(i)

# %%
#W4A20
def kiem_tra_luy_thua2(a):
    while a > 1:       
        if a%2 != 0 or a == 1:
            return False
        else:
            a = a//2
    return True
a = int(input())
print(kiem_tra_luy_thua2(a))
# Out:
#  23
# False

# %%
#W4A21
n = (input("N:"))
n.split()
number_addition = 0
for i in range(0,len(n)):
    number = int(n[i])
    number_addition += number

print(number_addition)

# %%
#W4A22
n = (input("N:"))
n.split()
number_even = 0
number_odd = 0
for i in range(0,len(n)):
    number = int(n[i])
    if number % 2 == 0:
        number_even += 1
    else:
        number_odd += 1
        
print(f"the number of even numbers is {number_even}")
print(f"the number of odd numbers is {number_odd}")

# %%
#W4A23

n = int(input("n: "))
S = 0
for i in range (1,n):
    S += i
    if S<n:
        continue
    else:
        break
    

print(i-1)
# Out:
# n:  6
# 2

# %%
#W4A24
A = float(input("A: "))
while S <= A:
    i += 1
    S += 1/i
print(i)
# Out:
# A:  6
# 83

# %%
#W4A25
is_true = True
list_of_Zs = []
while is_true:
    A = int(input(" "))
    if not A == -1:
        list_of_Zs.append(A)
    else:
        is_true = False

print(f"so be nhat la {min(list_of_Zs)}")
print(f"so to nhat la {max(list_of_Zs)}")

# %%
#W4A26

A = int(input("enter number A: "))
fi_list = [1,1]
i = 0
sum = 0

while sum < A:
    i += 1
    sum = fi_list[i-1] + fi_list[i]
    fi_list.append(sum)
    
print(fi_list[i])
# Out:
# enter number A:  6
# 5

# %%
#W4A27
is_True = True
while is_True:
    string = str(input("enter string here: "))
    num_of_characters = 0    
    if string.lower() == "q":
        is_True = False
    if num_of_characters == 0:
        print(" ")
    for i in string:
        if i.isalpha() == True or i ==" ":
            num_of_characters += 1
        else:
            print("string cannot contain any special characters or numbers ")
            break
    print(num_of_characters)

# %%
#W4A28
string = str(input("enter string here: "))
print(string[0])

# %%
#W4A29
strings_of_numbers = str(input("enter 3 integers ( each separated by ,): "))

string_number = strings_of_numbers.split(",")

sum_of_3 = 0

for i in range (0,3):
    sum_of_3 += int(string_number[i])
    
print(sum_of_3)

# %%
#W4A30
string = str(input(" "))
alpha_count = 0
number_count = 0
cap_count = 0   
for i in string:
    if i.isupper() == True:
        cap_count+=1
    elif i.isalpha() == True:
        alpha_count+=1
    elif i.isdigit() == True:
        number_count+=1
        
print(f"captilized letters: {cap_count}, alphabetical characters: {alpha_count}, numerical characters: {number_count}")

# %%
#W4A31
string = (input(" "))
num_list = []
sum = 0
for i in string:
    if i.isdigit() == True:
        num_list.append(i)
    else:
        pass

for i in num_list:
    sum += int(i)
    
print(sum)

# %% [markdown]
# #W4A32
#
# special_characters = [
#     ".", ",", "?", "!", ":", ";", "'", '"', "(", ")", "[", "]", "{", "}",
#     "-", "—", "…", " ", "+", "*", "/", "=", "<", ">", "%", "@", "#", "&",
#     "\\", "|", "_", "~", "`", "^", "$", "€", "£", "¥", "©", "®", "™", "°",
#     "§", "†", "•"
# ]
#
#
#
# def password_evaluation(password):
#     cap_count = 0
#     num_count = 0
#     spec_char_count = 0
#     all_char_count = 0
#     for char in password:
#         all_char_count += 1
#         if char in special_characters:
#             spec_char_count += 1
#         elif char.isupper() == True:
#             cap_count += 1
#         elif char.isdigit() == True:
#             num_count += 1
#     if num_count> 0 and cap_count>0 and spec_char_count>0 and all_char_count>6:
#         return"this is a strong password!!!!!"
#     else:
#         return"this password is not strong enough"
#
#
# password = input("")
#
# print(password_evaluation(password))

# %% [markdown]
# #W4A33
# def  sep_every_3_chars(string):
#     result = ""
#     for i in range(0,len(string),3):
#         result += string[i:i+3]
#         if i +3 <len(string):
#             result += "."
#         else:
#             return result
#
#
#
#
# string = (input("number: "))
# string = str(string)
# print(sep_every_3_chars(string))

# %% [markdown]
# #W4A34
# def char_del(string,string2):
#     string = string.split()
#     string2 = string2.split()
#     new_string = []
#     for i in string:
#         if i in string2:
#             continue
#         else:
#             new_string.append(i)
#
#     for k in new_string:
#         print(k,end=" ")
#
#     return ""
#
#
#
# A = str(input(""))
# B = str(input(""))
#
#
#
# print(char_del(A,B))
