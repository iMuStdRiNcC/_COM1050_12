# %%
#bai1
import math

Znumber= int(input("enter n number here: "))
while Znumber > 1:
    number = Znumber % 10 
    number = math.floor(number)
    print(number, end=" ")
    Znumber = Znumber /10

# %%
#BAI2
a = 1
b = 2

a = a^b
b = a^b
a = a^b

print(a,b)

# %%
#bai3
input = int(input("enter number for no reason what so ever lol: "))
if input&(input - 1)==0:
    print(True)
else:
    print(False)

# %%
#bai4
import math


a = int(input(" "))
b = int(input(" "))

print(math.floor(a/b))

# %%
#bai 5


a = int(input(" "))

if a%2 == 0:
    print("Even")
else:
    print("Odd")

# %%
#bai 6

a = int(input(" "))

b = int(input(" "))
    
if a > 0 and b > 0:
    print ("yes")
else:
    print ("no")

# %%
#bai7

a = input(" ")

b = input(" ")
    
if len(a) > len(b):
    print("True")
else:
    print("False")

# %%
#bai8
while True:
    a = (input("enter side 1(q to quit): "))
    b = (input("enter side 2(q to quit): "))
    c = (input("enter side 3(q to quit): "))
    if a == "q" or b == "q" or c == "q":
        break
    else:
        a=int(a)
        b=int(b)
        c=int(c)
        if a+b>c and a+c>b and b+c>a:
            print("this is a triangle alright")
        else:
            print("it's not a triangle ")

# %%
#bai9
a = int(input(" "))

b = int(input(" "))
    
c = int(input(" "))

d = int(input(" "))

if a > b and a> c and a>d:
    print(a)
elif b > a and b> c and b>d:
    print(b)
elif c > a and c> b and c>d:
    print(c)
else:
    print(d)

# %%
#bai9


a = int(input(" "))

b = int(input(" "))
    
c = int(input(" "))



if a == b == c:
    print("tam giac deu")
elif a == b or a == c or b == c:
    print("tam gac can")
elif a+b>c and a+c>b and b+c>a:
    print("tam giac thuong")
else:
    print("ko phai tam giac")

# %%
#bai11
a = int(input(" "))

if (a%4) == 0 and not (a%100) == 0 or a%400 == 0:
    print('nam nhuan')
else: 
    print("ko phai nam nhuan")

# %%
#bai12
score = float(input("Nhập điểm trung bình: "))

if score >= 8.0:
    print("Giỏi")
elif score >= 6.5:
    print("Khá")
elif score >= 5.0:
    print("Trung bình")
else:
    print("Yếu")

# %%
#bai13
a = float(input(" "))

rounded_down = a//1
rounded_up = int(-(-a//1))

rounded_to_nearest_integer = int(-(-a//1)) if a - int(a) >0.5 else a//1 

print(f"{rounded_up} {rounded_down}  {rounded_to_nearest_integer} ")
