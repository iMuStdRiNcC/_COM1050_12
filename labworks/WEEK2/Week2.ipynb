# %%
#bai1
n = int(input("Enter yo number here fool: "))

print (2*n)
# Out:
# hello world

# %%
#bai2
n = int(input("Enter yo number here fool: "))

print (2*n)

# %%
#bai3
c = input(" ")
if c.isupper():
    c= c.lower()
else:
    c= c.upper()
    
print (c)

# %%
#bai4
c = input("Enter yo bitch here: ")
if c.isalpha():
    print("c thuoc aplhabet")
else:
    print("c khong thuoc alhpabet")

# %%
#bai5
c=input("enter letter here: ")
print(f"{c.lower()}{c.upper()}")

# %%
#bai6
while True:
    a = (input("enter side 1(q to quit): "))
    b = (input("enter side 2(q to quit): "))
    c = (input("enter side 3(q to quit): "))
    if a == "q" or b == "q" or c == "q":
        break
    else:
        a=int(a)
        b=int(b)
        c=int(c)
        if a+b>c and a+c>b and b+c>a:
            print("this is a triangle alright")
        else:
            print("it's not a triangle ")
